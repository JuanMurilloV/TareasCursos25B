# %%
import sympy
from sympy import *

#Definir variable y limites de integracion:
t = symbols('t')
a, b = -1, 1

#Definir las funciones base como vectores:
base = [Matrix([1]), Matrix([t]), Matrix([t**2]), Matrix([t**3]), Matrix([t**4])]

#Definir el producto interno:
def producto(f, g):
  return integrate (f[0]*g[0]*sqrt(1-(t**2)), (t, a, b))

#Realizar Gram-Schimdt (para ortogonalizar)

ortogonalizados = []
for v in base:
  u = v
  for o in ortogonalizados:
    u -= (producto(v, o) / producto(o, o)) * o
  ortogonalizados.append(u)

#Mostrar Resultado

FiniteSet(*ortogonalizados)
# Out:
# {Matrix([[1]]), Matrix([[t]]), Matrix([[t**2 - 1/4]]), Matrix([[t**3 - t/2]]), Matrix([[t**4 - 3*t**2/4 + 1/16]])}

# %%
e1 = ortogonalizados[0]
e2 = ortogonalizados[1]
e3 = ortogonalizados[2]
e4 = ortogonalizados[3]
e5 = ortogonalizados[4]

vectores = [e1, e2, e3, e4, e5]
ortogonales = True
for i, vi in enumerate(vectores):
  for j, vj in enumerate(vectores):
    if j > i:
      resultado = producto(vi, vj)
      print(f"Producto interno entre e{i+1} y e{j+1}: {resultado}")
      if resultado != 0:
        ortogonales = False

#Mostrar Resultados
if ortogonales:
  print("El conjunto de vectores es ortogonal.")
else:
  print("El conjunto de  vectores no es ortogonal.")
# Out:
# Producto interno entre e1 y e2: 0
# Producto interno entre e1 y e3: 0
# Producto interno entre e1 y e4: 0
# Producto interno entre e1 y e5: 0
# Producto interno entre e2 y e3: 0
# Producto interno entre e2 y e4: 0
# Producto interno entre e2 y e5: 0
# Producto interno entre e3 y e4: 0
# Producto interno entre e3 y e5: 0
# Producto interno entre e4 y e5: 0
# El conjunto de vectores es ortogonal.
